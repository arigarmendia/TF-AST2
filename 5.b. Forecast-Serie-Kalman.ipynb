# %% [markdown]
# # Análisis de Series de Tiempo II
#
# ### Entrenamiento y pronóstico con la serie suavizada con filtro de Kalman.
#
# ---
#
# Entrenamos 4 modelos para predecir el delta de temperatura (LST).
#
# - Holt-Winters (baseline)
# - LSTM
# - GRU
# - Transformer
#
# En todos los casos se utilizaron los mismos hiperparámetros que para el entrenamiento con la serie sin suavizar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from colores import colores

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
import os
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %% [markdown]
# Los datos se encuentran en la carpeta csv:
# - ts_imputado_*: las LST de los 5 años, para pino y para estepa, con los faltantes ya imputados por diferentes métodos.

# %%
# Temperaturas diurnas (diarias)
# archivo = "csv/ts_imputado_bilstm.csv" # imputaciones con BiLSTM
# 
archivo = "csv/ts_imputado_bilstm_k.csv"   # imputaciones con BiLSTM + filtro de Kalman

df_d_diaria = pd.read_csv(archivo, parse_dates=["fecha"],
    dtype={"pino": "float64",
           "estepa": "float64",
           "mes": "int64",
           "delta": "float64"
          })

df_d_diaria.head(10)
# Out:
#        fecha     estepa       pino  mes     delta
# 0 2020-01-01  25.248988  22.406258    1  2.842729
# 1 2020-01-02  28.261892  24.635487    1  3.626405
# 2 2020-01-03  29.688001  25.523245    1  4.164756
# 3 2020-01-04  30.002555  25.258818    1  4.743737
# 4 2020-01-05  28.553355  23.756093    1  4.797261
# 5 2020-01-06  27.876731  23.415669    1  4.461062
# 6 2020-01-07  27.767456  23.207273    1  4.560183
# 7 2020-01-08  28.093476  23.735724    1  4.357751
# 8 2020-01-09  28.839865  24.335628    1  4.504237
# 9 2020-01-10  30.050188  25.055875    1  4.994313

# %% [markdown]
# ---
# ## Preparación de datos para entrenamiento
#
# Se entrenarán modelos para estimar el delta de temperatura diarias diurna

# %%
df_serie = df_d_diaria[['fecha','delta']] # datos diarios sin gaps

df_serie = df_serie.set_index('fecha')
df_serie.index = pd.to_datetime(df_serie.index)
df_serie.head()
# Out:
#                delta
# fecha
# 2020-01-01  2.842729
# 2020-01-02  3.626405
# 2020-01-03  4.164756
# 2020-01-04  4.743737
# 2020-01-05  4.797261

# %% [markdown]
# #### Split train y test

# %%
train_size = int(len(df_serie) * 0.8)  # 80 % entrenamiento, 20 % test
train_size # puntos
# Out:
# 1461

# %%
train = df_serie['delta'].iloc[:train_size]
test = df_serie['delta'].iloc[train_size:]

plt.figure(figsize=(10, 3))
plt.plot(train, label='Entrenamiento', color=colores['train'])
plt.plot(test, label='Prueba', color=colores['test'])
plt.legend(loc='lower left')

plt.grid(axis='y')
plt.title('Datos de entrenamiento y test - Delta de LST diurnas')
plt.show()

# %%
# Cuántos datos hay por año?
train.groupby(train.index.year).count()
# Out:
# fecha
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# Name: delta, dtype: int64

# %%
test.groupby(test.index.year).count()
# Out:
# fecha
# 2024    366
# Name: delta, dtype: int64

# %% [markdown]
# #### Split

# %%
# función para crear secuencias
def create_sequences(data, seq_length, target_idx=0):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length, target_idx])
    return np.array(X), np.array(y)

# %%
# Escala
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(df_serie['delta'].values.reshape(-1,1))

# Crea secuencias sobre toda la serie
seq_length = 182 # medio año
X, y = create_sequences(data_scaled, seq_length=seq_length)

test_points = 366  # 1 año

# convertir puntos a número de secuencias
test_sequences = test_points
train_sequences = len(X) - test_sequences

X_train, y_train = X[:train_sequences], y[:train_sequences]
X_test,  y_test  = X[train_sequences:], y[train_sequences:]

# %%
# Índices y variables auxiliares para los plots

# cantidad de secuencias del train
train_size_sec = len(X_train)

# posición real en la serie original
train_end_real = train_size_sec + seq_length  # 1279 + 182 = 1461
offset = train_end_real

datos_train = df_serie['delta'].iloc[:offset]
datos_test = df_serie['delta'].iloc[offset:]

index_train = df_serie.index[:offset]
index_test = df_serie.index[offset:]
index_forecast = df_serie.index[offset : offset + len(X_test)]

# %% [markdown]
# ---
# ## Entrenamiento

# %%
def guardar_estadisticas( modelo, mae, mse, rmse, imprimir=True):
    if modelo in df_resultados['Modelo'].values:
        df_resultados.loc[df_resultados['Modelo'] == modelo, [ 'MAE', 'MSE', 'RMSE']] = [mae, mse, rmse]
    else:
        df_resultados.loc[len(df_resultados)] = [modelo, mae, mse, rmse]
    if imprimir:
        print(f"modelo {modelo}")
        print(f"MAE  : {mae:.4f}")
        print(f"MSE  : {mse:.4f}")
        print(f"RMSE : {rmse:.4f}")

# Dataframe para guardar los resultados
df_resultados = pd.DataFrame(columns=['Modelo', 'MAE', 'MSE', 'RMSE'])

# %% [markdown]
# ### Modelo baseline Holt-Winters
#
# El modelo Holt-Winters es una extensión del suavizado exponencial que permite modelar series temporales con tendencia y estacionalidad. Este modelo no requiere que la serie sea estacionaria, ya que incorpora explícitamente componentes de nivel, tendencia y estacionalidad.

# %% [markdown]
# #### Resultados de Optuna para Holt-Winters:
#
# - Mejores params: {'trend': 'add', 'seasonal': 'add', 'use_boxcox': False, 'alpha': 0.05250488218458049, 'beta': 0.24427161109037507, 'gamma': 0.3076931343436633, 'phi': 0.9620148907784558, 'damped_trend': True}

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tools.sm_exceptions import ValueWarning
warnings.simplefilter("ignore", ValueWarning)

# %%
# Ajusta el modelo Holt-Winters
model_hw = ExponentialSmoothing(
    datos_train,
    trend='add',
    seasonal= 'add',
    seasonal_periods=365,
    use_boxcox= False,
    damped_trend= True,
    initialization_method='heuristic'
)

alpha= 0.05250488218458049
beta = 0.24427161109037507
gamma= 0.3076931343436633
phi= 0.9620148907784558
    
fit = model_hw.fit(
    smoothing_level=alpha,
    smoothing_slope=beta,
    smoothing_seasonal=gamma,
    damping_slope=phi,
    optimized=False 
)

# Genera el pronóstico
forecast_hw = fit.forecast(len(datos_test))

# %%
# Visualizar resultados
plt.figure(figsize=(12, 5))

plt.plot(train.index, df_serie['delta'].iloc[:train_size], label='Entrenamiento', color=colores['train'])
plt.plot(test.index, df_serie['delta'].iloc[train_size:], label='Prueba', color=colores['test'])
plt.plot(test.index, forecast_hw, label='Pronóstico', color=colores['otro'])
plt.title('Pronóstico Holt-Winters')
plt.xlabel('Fecha')
plt.ylabel('Temperatura (°C)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
mae_hw = mean_absolute_error(test,forecast_hw)
mse_hw = mean_squared_error(test,forecast_hw)
rmse_hw = np.sqrt(mean_squared_error(test,forecast_hw))

guardar_estadisticas('BASELINE', mae_hw, mse_hw, rmse_hw)
# Out:
# modelo BASELINE
# MAE  : 0.6203
# MSE  : 0.6056
# RMSE : 0.7782

# %% [markdown]
# ### a) LSTM
#
# El modelo LSTM (Long Short-Term Memory) es un tipo de red neuronal recurrente diseñada para capturar dependencias de largo plazo en series temporales. LSTM no requiere que la serie sea estacionaria y puede aprender patrones complejos no lineales en los datos, incluyendo tendencias, estacionalidades y efectos de interacciones pasadas.

# %% [markdown]
# #### Resultados de Optuna para LSTM:
#
# - Mejores params: {'units1': 32, 'units2': 24, 'dropout1': 0.30000000000000004, 'dropout2': 0.30000000000000004, 'lr': 0.0011982448134112169, 'batch_size': 64, 'n_layers': 1}

# %%
# Modelo LSTM (1 capa)
    
set_seed(42)
input_shape = (seq_length, 1)
model = Sequential([
    Input(shape=input_shape),
    LSTM(32, activation='tanh', return_sequences=False),
    Dropout(0.30000000000000004),
    Dense(1)
])

# Compila el modelo
model.compile(optimizer=Adam(learning_rate=0.0011982448134112169), loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Entrena el modelo
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stopping],
    verbose=1)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.2302 - val_loss: 0.0735
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.1212 - val_loss: 0.0382
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0549 - val_loss: 0.0247
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0312 - val_loss: 0.0237
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0291 - val_loss: 0.0224
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0271 - val_loss: 0.0216
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0249 - val_loss: 0.0208
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0224 - val_loss: 0.0203
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0228 - val_loss: 0.0196
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0214 - val_loss: 0.0190
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0204 - val_loss: 0.0184
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0185 - val_loss: 0.0179
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0197 - val_loss: 0.0175
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0191 - val_loss: 0.0168
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0170 - val_loss: 0.0159
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0163 - val_loss: 0.0155
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0158 - val_loss: 0.0151
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0161 - val_loss: 0.0147
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0147 - val_loss: 0.0143
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0154 - val_loss: 0.0139
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0140 - val_loss: 0.0132
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0133 - val_loss: 0.0128
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0126 - val_loss: 0.0125
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0134 - val_loss: 0.0123
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0124 - val_loss: 0.0118
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0118 - val_loss: 0.0117
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0122 - val_loss: 0.0113
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0123 - val_loss: 0.0107
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0112 - val_loss: 0.0103
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0101 - val_loss: 0.0103
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0104 - val_loss: 0.0098
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0114 - val_loss: 0.0094
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0103 - val_loss: 0.0093
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0104 - val_loss: 0.0090
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0100 - val_loss: 0.0086
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0093 - val_loss: 0.0087
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0105 - val_loss: 0.0083
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0095 - val_loss: 0.0081
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0090 - val_loss: 0.0077
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0091 - val_loss: 0.0075
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0084 - val_loss: 0.0072
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0082 - val_loss: 0.0069
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0085 - val_loss: 0.0068
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0083 - val_loss: 0.0066
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0081 - val_loss: 0.0064
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0080 - val_loss: 0.0061
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0079 - val_loss: 0.0056
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0081 - val_loss: 0.0054
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0076 - val_loss: 0.0055
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0073 - val_loss: 0.0053
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0075 - val_loss: 0.0051
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0072 - val_loss: 0.0051
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0082 - val_loss: 0.0049
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0066 - val_loss: 0.0047
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0061 - val_loss: 0.0046
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0066 - val_loss: 0.0043
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0069 - val_loss: 0.0043
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0066 - val_loss: 0.0043
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0062 - val_loss: 0.0040
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0064 - val_loss: 0.0040
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0064 - val_loss: 0.0039
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0061 - val_loss: 0.0039
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0059 - val_loss: 0.0039
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0077 - val_loss: 0.0038
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0068 - val_loss: 0.0036
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0063 - val_loss: 0.0036
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0058 - val_loss: 0.0036

# %%
# Generar pronósticos
set_seed(42)
forecast_scaled = model.predict(X_test)
forecast_lstm = scaler.inverse_transform(forecast_scaled)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Visualizar resultados

plt.figure(figsize=(12, 5))
plt.plot(index_train, datos_train, label="Entrenamiento", color=colores['train'])
plt.plot(index_test, datos_test, label="Prueba", color=colores['test'])
plt.plot(index_forecast, forecast_lstm, label="Predicción LSTM", color=colores['LSTM'])

plt.title('Pronóstico LSTM')
plt.xlabel('Fecha')
plt.ylabel('Delta de temperatura (°C)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Calcular métricas de error

mae = mean_absolute_error(datos_test, forecast_lstm)
mse = mean_squared_error(datos_test, forecast_lstm)
rmse = np.sqrt(mse)

guardar_estadisticas('LSTM',mae, mse, rmse)
# Out:
# modelo LSTM
# MAE  : 0.1712
# MSE  : 0.0528
# RMSE : 0.2299

# %% [markdown]
# ### b) GRU
#
# El modelo GRU (Gated Recurrent Unit) es una variante simplificada y más eficiente de la LSTM, también diseñada para modelar dependencias de largo plazo en series temporales. Utiliza solo dos compuertas (update y reset) en lugar de tres, lo que reduce significativamente el número de parámetros y acelera tanto el entrenamiento como la inferencia, manteniendo un rendimiento comparable o incluso superior en muchas tareas. Al igual que la LSTM, no necesita estacionariedad y aprende automáticamente tendencias, ciclos y relaciones no lineales complejas entre eventos pasados y futuros.

# %% [markdown]
# #### Resultados de Optuna para GRU:
#
# - Mejores params: {'units1': 64, 'units2': 48, 'dropout1': 0.4, 'dropout2': 0.2, 'lr': 0.0009420655442125198, 'batch_size': 16, 'n_layers': 1}

# %%
# Modelo GRU
set_seed(42)
input_shape = (seq_length, 1)
model = Sequential([
    Input(shape=input_shape),
    GRU(64, activation='tanh', return_sequences=False),
    Dropout(0.4),
    Dense(1)
])

# Compila el modelo
model.compile(optimizer=Adam(learning_rate=0.0009420655442125198), loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Entrena el modelo
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=16,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stopping],
    verbose=1)
# Out:
# Epoch 1/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.1087 - val_loss: 0.0120
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0142 - val_loss: 0.0109
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0127 - val_loss: 0.0098
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0116 - val_loss: 0.0088
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0093 - val_loss: 0.0080
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0089 - val_loss: 0.0075
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0088 - val_loss: 0.0068
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0080 - val_loss: 0.0060
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0048 - val_loss: 0.0034
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 0.0044 - val_loss: 0.0033
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0055 - val_loss: 0.0032
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0052 - val_loss: 0.0031
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0048 - val_loss: 0.0030
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0044 - val_loss: 0.0033
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0056 - val_loss: 0.0030
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0055 - val_loss: 0.0031
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0049 - val_loss: 0.0032

# %%
# Generar pronósticos
set_seed(42)
forecast_scaled = model.predict(X_test)
forecast_gru = scaler.inverse_transform(forecast_scaled)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# Visualizar resultados

plt.figure(figsize=(12, 5))
plt.plot(index_train, datos_train, label="Entrenamiento", color=colores['train'])
plt.plot(index_test, datos_test, label="Prueba", color=colores['test'])
plt.plot(index_forecast, forecast_gru, label="Predicción GRU", color=colores['GRU'])

plt.title('Pronóstico GRU')
plt.xlabel('Fecha')
plt.ylabel('Delta de temperatura (°C)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Visualizar la pérdida durante el entrenamiento
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Pérdida durante el entrenamiento de la GRU')
plt.xlabel('Época')
plt.ylabel('Pérdida (MSE)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Calcular métricas de error
mae = mean_absolute_error(datos_test, forecast_gru)
mse = mean_squared_error(datos_test, forecast_gru)
rmse = np.sqrt(mse)

guardar_estadisticas('GRU',mae, mse, rmse)
# Out:
# modelo GRU
# MAE  : 0.1492
# MSE  : 0.0416
# RMSE : 0.2041

# %% [markdown]
# ### c) Transformer
#
# Los Transformers representan un cambio fundamental respecto LSTM y GRU en series temporales, porque eliminan la recurrencia y usan atención para capturar dependencias entre cualquier par de puntos en la secuencia, sin importar la distancia temporal. Son especialmente potentes para detectar patrones complejos, interacciones no locales y relaciones de múltiples escalas temporales (diarias, semanales, anuales) en una sola pasada.

# %% [markdown]
# #### Resultados de Optuna para Transformer:
#
# - Mejores params: {'d_model': 80, 'n_heads': 4, 'n_layers': 3, 'ff_dim': 224, 'dropout': 0.15000000000000002, 'final_dropout': 0.4, 'lr': 0.0020244831112923374, 'batch_size': 32}

# %%
# Transformer
set_seed(42)

class PositionalEncoding(layers.Layer):
    def __init__(self, seq_len, d_model):
        super().__init__()
        self.seq_len = seq_len
        self.d_model = d_model
        
        # Crea matriz de positional encoding (sinusoide fija)
        pe = np.zeros((seq_len, d_model))
        position = np.arange(0, seq_len)[:, np.newaxis]
        div_term = np.exp(np.arange(0, d_model, 2) * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = np.sin(position * div_term)
        pe[:, 1::2] = np.cos(position * div_term)
        pe = pe[np.newaxis, ...]  # (1, seq_len, d_model)
        self.pe = tf.constant(pe, dtype=tf.float32)
    
    def call(self, inputs):
        return inputs + self.pe[:, :tf.shape(inputs)[1], :]


def build_transformer(d_model=64, n_heads=4, n_layers=2, ff_dim=128, dropout=0.1, final_dropout=0.2):

    seq_length = X_train.shape[1]
    n_features = X_train.shape[2]

    inputs = Input(shape=(seq_length, n_features))
    
    # 1. Proyección lineal a d_model
    x = layers.Dense(d_model)(inputs)
    
    # 2. POSITIONAL ENCODING
    x = PositionalEncoding(seq_length, d_model)(x)
    
    # 3. Bloques Transformer
    for _ in range(n_layers):
        # Multi-Head Self Attention
        attn_output = layers.MultiHeadAttention(
            num_heads=n_heads, key_dim=d_model//n_heads, dropout=dropout
        )(x, x)
        attn_output = layers.Dropout(dropout)(attn_output)
        x1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
        
        # Feed Forward
        ff = layers.Dense(ff_dim, activation='relu')(x1)
        ff = layers.Dense(d_model)(ff)
        ff = layers.Dropout(dropout)(ff)
        x = layers.LayerNormalization(epsilon=1e-6)(x1 + ff)

        
    # 4. Salida
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(final_dropout)(x)
    outputs = layers.Dense(1)(x)
    
    model = Model(inputs, outputs)
    return model
    
model = build_transformer(d_model=80, n_heads=4, n_layers=3, ff_dim=224,
                          dropout=0.15000000000000002, final_dropout=0.4)

# Compila el modelo
model.compile(optimizer=Adam(learning_rate=0.0020244831112923374),
              loss='mse', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),

# Entrena el modelo
history = model.fit(X_train, y_train, validation_split=0.2, shuffle=False, 
                    epochs=100, batch_size=32, callbacks=early_stopping,verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 460ms/step - loss: 5.3155 - mae: 1.6297 - val_loss: 0.0680 - val_mae: 0.2269
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - loss: 0.3787 - mae: 0.4929 - val_loss: 0.2716 - val_mae: 0.4529
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 475ms/step - loss: 0.3124 - mae: 0.4641 - val_loss: 0.1912 - val_mae: 0.3669
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - loss: 0.2909 - mae: 0.4656 - val_loss: 0.2007 - val_mae: 0.3778
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 443ms/step - loss: 0.2531 - mae: 0.4318 - val_loss: 0.1885 - val_mae: 0.3645
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - loss: 0.2302 - mae: 0.4098 - val_loss: 0.1899 - val_mae: 0.3670
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - loss: 0.2288 - mae: 0.4101 - val_loss: 0.1807 - val_mae: 0.3596
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 471ms/step - loss: 0.2068 - mae: 0.3934 - val_loss: 0.2015 - val_mae: 0.4030
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 505ms/step - loss: 0.1779 - mae: 0.3560 - val_loss: 0.2206 - val_mae: 0.4381
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 463ms/step - loss: 0.1400 - mae: 0.3025 - val_loss: 0.0777 - val_mae: 0.2361
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 462ms/step - loss: 0.0814 - mae: 0.2281 - val_loss: 0.0681 - val_mae: 0.2211
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 517ms/step - loss: 0.0940 - mae: 0.2485 - val_loss: 0.2696 - val_mae: 0.4733
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 478ms/step - loss: 0.1772 - mae: 0.3318 - val_loss: 0.0655 - val_mae: 0.2044
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 502ms/step - loss: 0.0586 - mae: 0.1907 - val_loss: 0.1198 - val_mae: 0.2985
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 552ms/step - loss: 0.0944 - mae: 0.2460 - val_loss: 0.0412 - val_mae: 0.1559
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 490ms/step - loss: 0.0614 - mae: 0.2043 - val_loss: 0.1261 - val_mae: 0.3200
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 527ms/step - loss: 0.0659 - mae: 0.2039 - val_loss: 0.0977 - val_mae: 0.2759
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 474ms/step - loss: 0.0375 - mae: 0.1515 - val_loss: 0.0606 - val_mae: 0.1997
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 442ms/step - loss: 0.0412 - mae: 0.1567 - val_loss: 0.0814 - val_mae: 0.2420
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 467ms/step - loss: 0.0480 - mae: 0.1725 - val_loss: 0.0783 - val_mae: 0.2384
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 445ms/step - loss: 0.0418 - mae: 0.1551 - val_loss: 0.0545 - val_mae: 0.1870
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 489ms/step - loss: 0.0469 - mae: 0.1586 - val_loss: 0.0667 - val_mae: 0.2129
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 493ms/step - loss: 0.0542 - mae: 0.1757 - val_loss: 0.0470 - val_mae: 0.1723
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 464ms/step - loss: 0.0602 - mae: 0.1944 - val_loss: 0.0784 - val_mae: 0.2275
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 481ms/step - loss: 0.1031 - mae: 0.2762 - val_loss: 0.1168 - val_mae: 0.2901
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 484ms/step - loss: 0.0597 - mae: 0.1896 - val_loss: 0.0479 - val_mae: 0.1765
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 468ms/step - loss: 0.0819 - mae: 0.2403 - val_loss: 0.0664 - val_mae: 0.2073
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 486ms/step - loss: 0.0759 - mae: 0.2312 - val_loss: 0.0302 - val_mae: 0.1288
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 506ms/step - loss: 0.0535 - mae: 0.1649 - val_loss: 0.0252 - val_mae: 0.1220
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 525ms/step - loss: 0.0693 - mae: 0.2080 - val_loss: 0.0432 - val_mae: 0.1542
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 495ms/step - loss: 0.1533 - mae: 0.3060 - val_loss: 0.0252 - val_mae: 0.1264
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 485ms/step - loss: 0.0682 - mae: 0.2030 - val_loss: 0.0290 - val_mae: 0.1370
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 493ms/step - loss: 0.0922 - mae: 0.2524 - val_loss: 0.0661 - val_mae: 0.2358
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 464ms/step - loss: 0.1139 - mae: 0.2906 - val_loss: 0.1208 - val_mae: 0.3280
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 449ms/step - loss: 0.1545 - mae: 0.3491 - val_loss: 0.0763 - val_mae: 0.2562
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 473ms/step - loss: 0.1130 - mae: 0.2923 - val_loss: 0.0549 - val_mae: 0.2106
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 471ms/step - loss: 0.0939 - mae: 0.2598 - val_loss: 0.0412 - val_mae: 0.1765
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 465ms/step - loss: 0.0753 - mae: 0.2307 - val_loss: 0.0367 - val_mae: 0.1640
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 474ms/step - loss: 0.0639 - mae: 0.2128 - val_loss: 0.0332 - val_mae: 0.1543
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - loss: 0.0515 - mae: 0.1893 - val_loss: 0.0333 - val_mae: 0.1542
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 470ms/step - loss: 0.0437 - mae: 0.1716 - val_loss: 0.0323 - val_mae: 0.1503
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 477ms/step - loss: 0.0349 - mae: 0.1510 - val_loss: 0.0322 - val_mae: 0.1505
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 486ms/step - loss: 0.0317 - mae: 0.1454 - val_loss: 0.0301 - val_mae: 0.1464
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - loss: 0.0258 - mae: 0.1259 - val_loss: 0.0291 - val_mae: 0.1441
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - loss: 0.0280 - mae: 0.1327 - val_loss: 0.0308 - val_mae: 0.1518
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 477ms/step - loss: 0.0289 - mae: 0.1371 - val_loss: 0.0227 - val_mae: 0.1208
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 446ms/step - loss: 0.0191 - mae: 0.1085 - val_loss: 0.0223 - val_mae: 0.1197
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - loss: 0.0212 - mae: 0.1141 - val_loss: 0.0251 - val_mae: 0.1350
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 440ms/step - loss: 0.0233 - mae: 0.1214 - val_loss: 0.0276 - val_mae: 0.1419
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 447ms/step - loss: 0.0213 - mae: 0.1162 - val_loss: 0.0236 - val_mae: 0.1234
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 459ms/step - loss: 0.0160 - mae: 0.0996 - val_loss: 0.0201 - val_mae: 0.1129
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 449ms/step - loss: 0.0157 - mae: 0.0983 - val_loss: 0.0160 - val_mae: 0.0983
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 439ms/step - loss: 0.0167 - mae: 0.0990 - val_loss: 0.0151 - val_mae: 0.0981
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 477ms/step - loss: 0.0162 - mae: 0.0978 - val_loss: 0.0163 - val_mae: 0.1005
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 498ms/step - loss: 0.0122 - mae: 0.0847 - val_loss: 0.0126 - val_mae: 0.0821
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 529ms/step - loss: 0.0108 - mae: 0.0774 - val_loss: 0.0201 - val_mae: 0.1144
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 511ms/step - loss: 0.0101 - mae: 0.0785 - val_loss: 0.0154 - val_mae: 0.0960
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 459ms/step - loss: 0.0104 - mae: 0.0762 - val_loss: 0.0105 - val_mae: 0.0669
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 419ms/step - loss: 0.0151 - mae: 0.1003 - val_loss: 0.0121 - val_mae: 0.0721
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 429ms/step - loss: 0.0127 - mae: 0.0842 - val_loss: 0.0295 - val_mae: 0.1379
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 521ms/step - loss: 0.0121 - mae: 0.0855 - val_loss: 0.0213 - val_mae: 0.1147
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 561ms/step - loss: 0.0142 - mae: 0.0947 - val_loss: 0.0113 - val_mae: 0.0721
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 476ms/step - loss: 0.0125 - mae: 0.0833 - val_loss: 0.0210 - val_mae: 0.1194
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 546ms/step - loss: 0.0118 - mae: 0.0852 - val_loss: 0.0191 - val_mae: 0.1086
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 584ms/step - loss: 0.0116 - mae: 0.0849 - val_loss: 0.0124 - val_mae: 0.0813
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 591ms/step - loss: 0.0109 - mae: 0.0777 - val_loss: 0.0253 - val_mae: 0.1253
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 564ms/step - loss: 0.0116 - mae: 0.0834 - val_loss: 0.0165 - val_mae: 0.1015
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 574ms/step - loss: 0.0218 - mae: 0.1214 - val_loss: 0.0154 - val_mae: 0.0867
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 502ms/step - loss: 0.0158 - mae: 0.0942 - val_loss: 0.0235 - val_mae: 0.1215
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 495ms/step - loss: 0.0170 - mae: 0.1046 - val_loss: 0.0151 - val_mae: 0.0934
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 506ms/step - loss: 0.0112 - mae: 0.0787 - val_loss: 0.0301 - val_mae: 0.1381
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 543ms/step - loss: 0.0151 - mae: 0.0995 - val_loss: 0.0210 - val_mae: 0.1176
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 513ms/step - loss: 0.0141 - mae: 0.0936 - val_loss: 0.0170 - val_mae: 0.0992
# Epoch 73: early stopping
# Restoring model weights from the end of the best epoch: 58.

# %%
# Generar pronósticos
set_seed(42)
forecast_scaled = model.predict(X_test)
forecast_transf = scaler.inverse_transform(forecast_scaled.reshape(-1, 1)).ravel()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step

# %%
# Visualizar resultados

plt.figure(figsize=(12, 5))
plt.plot(index_train, datos_train, label="Entrenamiento", color=colores['train'])
plt.plot(index_test, datos_test, label="Prueba", color=colores['test'])
plt.plot(index_forecast, forecast_transf, label="Predicción Transformer", color=colores['TRANSFRMR'])

plt.title('Pronóstico Transformer')
plt.xlabel('Fecha')
plt.ylabel('Delta de temperatura (°C)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Visualizar la pérdida durante el entrenamiento
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Pérdida durante el entrenamiento del Transformer')
plt.xlabel('Época')
plt.ylabel('Pérdida (MSE)')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# Calcular métricas de error

mae = mean_absolute_error(datos_test, forecast_transf)
mse = mean_squared_error(datos_test, forecast_transf)
rmse = np.sqrt(mse)

guardar_estadisticas('TRANSFORMER',mae, mse, rmse)
# Out:
# modelo TRANSFORMER
# MAE  : 0.3611
# MSE  : 0.2078
# RMSE : 0.4558

# %% [markdown]
# ### Pronósticos (para todos los modelos)

# %%
# Número de puntos históricos a mostrar
n_last = 365 # un año de datos
train_recent = train[-n_last:]

fig, axes = plt.subplots(3, 1, figsize=(12, 12), sharex=True, sharey=True)

# Lista de pronósticos y nombres
forecasts = [forecast_lstm, forecast_transf, forecast_transf]
names = ['LSTM', 'GRU', 'TRANSFORMER']
colors = [colores['LSTM'], colores['GRU'], colores['TRANSFRMR']]

for ax, forecast, name, color in zip(axes, forecasts, names, colors):
    # Plot train reciente
    ax.plot(train_recent.index, train_recent.values, label=f'Train (últimos {n_last} valores)', color=colores['train'])
    # Plot test
    ax.plot(test.index, test.values, label='Test', color=colores['test'])
    # Plot pronóstico
    ax.plot(test.index, forecast, label=name, linestyle='--', lw=2, color=color)

    ax.set_title(name)
    ax.set_ylabel('Delta')
    ax.legend()
    ax.grid(True)

axes[-1].set_xlabel('Fecha')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Resultados

# %%
resultados = df_resultados.copy()
resultados.set_index('Modelo', inplace=True)
resultados
# Out:
#                   MAE       MSE      RMSE  Mejora vs Baseline (MAE)  \
# Modelo
# BASELINE     0.620336  0.605579  0.778190                  0.000000
# LSTM         0.171193  0.052834  0.229857                -72.403217
# GRU          0.149229  0.041645  0.204070                -75.943928
# TRANSFORMER  0.361078  0.207799  0.455849                 54.741647
#
#              Mejora vs Baseline (RMSE)
# Modelo
# BASELINE                      0.000000
# LSTM                        -70.462622
# GRU                         -73.776331
# TRANSFORMER                  47.404417

# %%
plt.figure(figsize=(6,3))
# sns.heatmap(resultados[['MAE','MSE','RMSE']].drop(index="BASELINE"), annot=True, fmt=".4f", cmap='Reds', cbar_kws={'label': 'Error'})
sns.heatmap(resultados[['MAE','MSE','RMSE']], annot=True, fmt=".4f", cmap='Reds', cbar_kws={'label': 'Error'})
plt.title('Heatmap de métricas por modelo')
plt.show()

# %% [markdown]
# Para confirmar si las métricas son razonables, las comparamos en relación al modelo baseline.

# %%
mae_seasonal = resultados.loc['BASELINE']['MAE']
rmse_seasonal = resultados.loc['BASELINE']['RMSE']

df_resultados['Mejora vs Baseline (MAE)'] = (df_resultados['MAE'] - mae_seasonal) / mae_seasonal * 100
df_resultados['Mejora vs Baseline (RMSE)'] = (df_resultados['RMSE'] - rmse_seasonal) / rmse_seasonal * 100

df_resultados
# Out:
#         Modelo       MAE       MSE      RMSE  Mejora vs Baseline (MAE)  \
# 0     BASELINE  0.620336  0.605579  0.778190                  0.000000
# 1         LSTM  0.171193  0.052834  0.229857                -72.403217
# 2          GRU  0.149229  0.041645  0.204070                -75.943928
# 3  TRANSFORMER  0.361078  0.207799  0.455849                -41.793204
#
#    Mejora vs Baseline (RMSE)
# 0                   0.000000
# 1                 -70.462622
# 2                 -73.776331
# 3                 -41.421820

# %% [markdown]
# ### Conclusiones
#
# - LSTM y GRU superaron por un margen notable al baseline.
# - El Transformer superó al baseline, pero no llegó a ser tan bueno con los otros modelos.
#
# Con respecto al entrenamiento con la serie ruidosa:
# - En todos los casos, los resultados fueron ampliamente superadores comparados con los obtenidos en el entrenamiento con la serie original.
# - GRU y LSTM fueron los que mejor performaron.
